# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniova127/Extraccion-de-caracteristicas/blob/main/Actividad_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
from google.colab import files
files.upload()

# %%
Micro_Retailer = pd.read_excel("microretailer_mit_lift_lab.xlsx")

# %%
pd.options.display.max_columns= None
Micro_Retailer.head(2)
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
#
#            228_store_name 229_store_picture               232_type_of_store  \
# 0     Eugene’s Compostura           1 Photo                          Tailor
# 1  Frutas y verduras Angy           1 Photo  Grocery store (aka. nanostore)
#
#   108_does_the_micro_retailer_has_a_barred_window_  \
# 0                                              yes
# 1                                               no
#
# ...

# %%
filtro3=Micro_Retailer.iloc[ : , [1,3,9,10,11,12,13,15,20,21,22,23,25,27,31,34,35,36,87,86]]  #columnas no consecutivas
filtro3
# Out:
#                 _title           _updated_by                232_type_of_store  \
# 0    November 12, 2022  Salomon Abdala Perez                           Tailor
# 1    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                 ...                   ...                              ...
# 166   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 167   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 168   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
# 169   November 3, 2022        Francisco Adán  Micro-restaurant (aka. fondita)
# 170   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
#
# ...

# %%
filtro3.isnull().sum()
# Out:
# _title                                                    0
# _updated_by                                               0
# 232_type_of_store                                         0
# 108_does_the_micro_retailer_has_a_barred_window_          0
# 99_does_the_micro_retailer_exhibits_products_outside_     0
# 102_does_the_micro_retailer_sells_fresh_products_         0
# 97_number_of_customers_in_store                           0
# 184_store_devices                                         2
# 233_date_establishment                                   59
# 2_current_permanent_employees                            60
# 4_number_permanent_employees_last_year                   76
# 5_change_store_space_last_year                           72
# 20_reviews_finances_monthly                              63
# 18_sales_records                                         61
# 145_number_direct_competitors                            68
# 186_internet_connection                                  63
# ...

# %%
data= filtro3.copy()

# %%
data["184_store_devices"]=data["184_store_devices"].fillna("smartphone")
data["233_date_establishment"]=data["233_date_establishment"].fillna("no register")
data["2_current_permanent_employees"]=data["2_current_permanent_employees"].fillna(round(filtro3["2_current_permanent_employees"].mean(),1))
data["4_number_permanent_employees_last_year"]=data["4_number_permanent_employees_last_year"].fillna(round(filtro3["4_number_permanent_employees_last_year"].median(),1))
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].fillna("sin registro")
data["20_reviews_finances_monthly"]=data["20_reviews_finances_monthly"].fillna("sin registro")
data["18_sales_records"]=data["18_sales_records"].fillna("18_sales_records")
data["145_number_direct_competitors"]=data["145_number_direct_competitors"].fillna(round(filtro3["2_current_permanent_employees"].mean(),1))
data["186_internet_connection"]=data["186_internet_connection"].fillna("sin registro")
data["210_sales_channels"]=data["210_sales_channels"].fillna("sin registro")
data["189_payment_methods"]=data["189_payment_methods"].fillna("sin registro")
data["158_charact_organize_products_on_shelves"]=data["158_charact_organize_products_on_shelves"].fillna("sin registro")
data["157_frequency_organize_shelves"]=data["157_frequency_organize_shelves"].fillna("sin registro")

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _title                                                   0
# _updated_by                                              0
# 232_type_of_store                                        0
# 108_does_the_micro_retailer_has_a_barred_window_         0
# 99_does_the_micro_retailer_exhibits_products_outside_    0
# 102_does_the_micro_retailer_sells_fresh_products_        0
# 97_number_of_customers_in_store                          0
# 184_store_devices                                        0
# 233_date_establishment                                   0
# 2_current_permanent_employees                            0
# 4_number_permanent_employees_last_year                   0
# 5_change_store_space_last_year                           0
# 20_reviews_finances_monthly                              0
# 18_sales_records                                         0
# 145_number_direct_competitors                            0
# 186_internet_connection                                  0
# ...

# %%
Cuantitativas=data.iloc[ : , [6,9,10,14]]
Cuantitativas
# Out:
#      97_number_of_customers_in_store  2_current_permanent_employees  \
# 0                                  2                            2.0
# 1                                  0                            1.0
# 2                                  0                            2.0
# 3                                  0                            1.0
# 4                                  0                            0.0
# ..                               ...                            ...
# 166                                1                            2.1
# 167                                1                            2.1
# 168                                3                            2.1
# 169                                0                            2.1
# 170                                1                            2.1
#
#      4_number_permanent_employees_last_year  145_number_direct_competitors
# 0                                       2.0                            3.0
# ...

# %%
Cualitativas=data.iloc[ : , [0,1,2,3,4,5,8,11,12,13,15,16,17,18,19]]
Cualitativas
# Out:
#                 _title           _updated_by                232_type_of_store  \
# 0    November 12, 2022  Salomon Abdala Perez                           Tailor
# 1    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                 ...                   ...                              ...
# 166   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 167   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 168   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
# 169   November 3, 2022        Francisco Adán  Micro-restaurant (aka. fondita)
# 170   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
#
# ...

# %%
fig = plt.figure(figsize =(15, 8))
Cuantitativas.plot(kind='box', vert=True)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y=(Cuantitativas)
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 97_number_of_customers_in_store            6.591777
# 2_current_permanent_employees             13.659862
# 4_number_permanent_employees_last_year    12.073899
# 145_number_direct_competitors             12.037539
# dtype: float64
# Limite inferior permitido 97_number_of_customers_in_store          -3.808151
# 2_current_permanent_employees            -9.507816
# 4_number_permanent_employees_last_year   -9.068051
# 145_number_direct_competitors            -5.841048
# dtype: float64

# %%
Datos_sin_Outliers= Cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
Datos_sin_Outliers
# Out:
#      97_number_of_customers_in_store  2_current_permanent_employees  \
# 0                                2.0                            2.0
# 1                                0.0                            1.0
# 2                                0.0                            2.0
# 3                                0.0                            1.0
# 4                                0.0                            0.0
# ..                               ...                            ...
# 166                              1.0                            2.1
# 167                              1.0                            2.1
# 168                              3.0                            2.1
# 169                              0.0                            2.1
# 170                              1.0                            2.1
#
#      4_number_permanent_employees_last_year  145_number_direct_competitors
# 0                                       2.0                            3.0
# ...

# %%
valores_nulos=Datos_sin_Outliers.isnull().sum()
valores_nulos
# Out:
# 97_number_of_customers_in_store           4
# 2_current_permanent_employees             1
# 4_number_permanent_employees_last_year    1
# 145_number_direct_competitors             4
# dtype: int64

# %%
data_clean=Datos_sin_Outliers.copy()
data_clean=data_clean.fillna(round(Datos_sin_Outliers.mean(),1))
data_clean
# Out:
#      97_number_of_customers_in_store  2_current_permanent_employees  \
# 0                                2.0                            2.0
# 1                                0.0                            1.0
# 2                                0.0                            2.0
# 3                                0.0                            1.0
# 4                                0.0                            0.0
# ..                               ...                            ...
# 166                              1.0                            2.1
# 167                              1.0                            2.1
# 168                              3.0                            2.1
# 169                              0.0                            2.1
# 170                              1.0                            2.1
#
#      4_number_permanent_employees_last_year  145_number_direct_competitors
# 0                                       2.0                            3.0
# ...

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# 97_number_of_customers_in_store           0
# 2_current_permanent_employees             0
# 4_number_permanent_employees_last_year    0
# 145_number_direct_competitors             0
# dtype: int64

# %%
Dataframe_final = pd.concat([Cualitativas, data_clean], axis=1)
Dataframe_final
# Out:
#                 _title           _updated_by                232_type_of_store  \
# 0    November 12, 2022  Salomon Abdala Perez                           Tailor
# 1    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    November 12, 2022  Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                 ...                   ...                              ...
# 166   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 167   November 3, 2022          Emilio Garza   Grocery store (aka. nanostore)
# 168   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
# 169   November 3, 2022        Francisco Adán  Micro-restaurant (aka. fondita)
# 170   November 3, 2022          Emilio Garza  Micro-restaurant (aka. fondita)
#
# ...

# %%
freq_tbl(Micro_Retailer)

# %%
table1=freq_tbl(Dataframe_final["_updated_by"])
table1
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# ...

# %%
Filtro=table1[table1["frequency"]>1]
Filtro
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# ...

# %%
Filtro_index=Filtro.set_index("_updated_by")
Filtro_index
# Out:
#                                    frequency  percentage  cumulative_perc
# _updated_by
# Salomon Abdala Perez                      20    0.116959         0.116959
# Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# José Zapata                               14    0.081871         0.292398
# Emilio Garza                              13    0.076023         0.368421
# Benjamin Barbosa                          13    0.076023         0.444444
# Pedro Contreras                           12    0.070175         0.514620
# Eduardo Zárate                             9    0.052632         0.567251
# Alejandro Matias                           8    0.046784         0.614035
# Harry Hernández                            7    0.040936         0.654971
# Francisco Adán                             7    0.040936         0.695906
# Hiram Jiménez                              6    0.035088         0.730994
# ...

# %%
Filtro_index.plot(kind="bar", width=1, figsize = (10,4))
plt.title("Herramientas de relacion con los clientes")
plt.xlabel("Tipo de Herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("Updated by")
# Out:
# Text(0.5, 1.0, 'Updated by')

# %%
table2=freq_tbl(Dataframe_final["232_type_of_store"])

# %%
Filtro1=table2[table2["frequency"]>1]
Filtro1
# Out:
#                  232_type_of_store  frequency  percentage  cumulative_perc
# 0   Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1  Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                   Dairy products         10    0.058480         0.543860
# 3                        Cafeteria          6    0.035088         0.578947
# 4                     Butcher shop          6    0.035088         0.614035
# 5    Produce (fruits & vegetables)          4    0.023392         0.637427
# 6               Handmade products           2    0.011696         0.649123
# 7                       Papelería           2    0.011696         0.660819
# 8                         objetos           2    0.011696         0.672515
# 9                      Ferretería           2    0.011696         0.684211

# %%
Filtro_index1=Filtro1.set_index("232_type_of_store")
Filtro_index1
# Out:
#                                  frequency  percentage  cumulative_perc
# 232_type_of_store
# Grocery store (aka. nanostore)          52    0.304094         0.304094
# Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# Dairy products                          10    0.058480         0.543860
# Cafeteria                                6    0.035088         0.578947
# Butcher shop                             6    0.035088         0.614035
# Produce (fruits & vegetables)            4    0.023392         0.637427
# Handmade products                        2    0.011696         0.649123
# Papelería                                2    0.011696         0.660819
# objetos                                  2    0.011696         0.672515
# Ferretería                               2    0.011696         0.684211

# %%
Filtro_index1.plot(kind="bar", width=1, figsize = (10,4))
plt.title("Herramientas de relacion con los clientes")
plt.xlabel("Tipo de Herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Filtro_index1["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("Tipo de tienda")
# Out:
# Text(0.5, 1.0, 'Tipo de tienda')

# %%
table3=freq_tbl(Dataframe_final["108_does_the_micro_retailer_has_a_barred_window_"])

# %%
Filtro2=table3[table3["frequency"]>1]
Filtro2
# Out:
#   108_does_the_micro_retailer_has_a_barred_window_  frequency  percentage  \
# 0                                               no        124    0.725146
# 1                                              yes         47    0.274854
#
#    cumulative_perc
# 0         0.725146
# 1         1.000000

# %%
Filtro_index2=Filtro2.set_index("108_does_the_micro_retailer_has_a_barred_window_")
Filtro_index2
# Out:
#                                                   frequency  percentage  \
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                      124    0.725146
# yes                                                      47    0.274854
#
#                                                   cumulative_perc
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                       0.725146
# yes                                                      1.000000

# %%
Filtro_index2["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Barred window?')
# Out:
# Text(0.5, 1.0, 'Barred window?')

# %%
table4=freq_tbl(Dataframe_final["99_does_the_micro_retailer_exhibits_products_outside_"])

# %%
Filtro3=table4[table4["frequency"]>1]
Filtro3
# Out:
#   99_does_the_micro_retailer_exhibits_products_outside_  frequency  \
# 0                                                 no           120
# 1                                                yes            51
#
#    percentage  cumulative_perc
# 0    0.701754         0.701754
# 1    0.298246         1.000000

# %%
Filtro_index3=Filtro3.set_index("99_does_the_micro_retailer_exhibits_products_outside_")
Filtro_index3
# Out:
#                                                     frequency  percentage  \
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                        120    0.701754
# yes                                                        51    0.298246
#
#                                                     cumulative_perc
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                         0.701754
# yes                                                        1.000000

# %%
Filtro_index3["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Exhibits products outside?')
# Out:
# Text(0.5, 1.0, 'Exhibits products outside?')

# %%
table4=freq_tbl(Dataframe_final["_title"])

# %%
Filtro4=table4[table4["frequency"]>1]
Filtro4
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304

# %%
Filtro_index4=Filtro4.set_index("_title")
Filtro_index4
# Out:
#                    frequency  percentage  cumulative_perc
# _title
# November 9, 2022          73    0.426901         0.426901
# November 10, 2022         26    0.152047         0.578947
# November 7, 2022          20    0.116959         0.695906
# November 3, 2022          16    0.093567         0.789474
# November 12, 2022         15    0.087719         0.877193
# November 8, 2022          10    0.058480         0.935673
# November 4, 2022           9    0.052632         0.988304

# %%
Filtro_index4["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("Fecha de registro")
# Out:
# Text(0.5, 1.0, 'Fecha de registro')

# %%
table5=freq_tbl(Dataframe_final["102_does_the_micro_retailer_sells_fresh_products_"])

# %%
Filtro5=table5[table5["frequency"]>1]
Filtro5
# Out:
#   102_does_the_micro_retailer_sells_fresh_products_  frequency  percentage  \
# 0                                                no        105    0.614035
# 1                                               yes         66    0.385965
#
#    cumulative_perc
# 0         0.614035
# 1         1.000000

# %%
Filtro_index5=Filtro5.set_index("102_does_the_micro_retailer_sells_fresh_products_")
Filtro_index5
# Out:
#                                                    frequency  percentage  \
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                       105    0.614035
# yes                                                       66    0.385965
#
#                                                    cumulative_perc
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                        0.614035
# yes                                                       1.000000

# %%
Filtro_index5["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Sell fresh products?')
# Out:
# Text(0.5, 1.0, 'Sell fresh products?')

# %%
table4= freq_tbl(Dataframe_final['233_date_establishment'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('233_date_establishment')
plt.title('Date establishment')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Date establishment'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['5_change_store_space_last_year'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('5_change_store_space_last_year')
plt.title('Change space?')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Change space?'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['20_reviews_finances_monthly'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('20_reviews_finances_monthly')
plt.title('Revisas mensualmente las finanzas?')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Revisas mensualmente las finanzas?'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['18_sales_records'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('18_sales_records')
plt.title('Sales register?')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Sales register?'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['186_internet_connection'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('186_internet_connection')
plt.title('Internet connection?')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Internet connection?'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['210_sales_channels'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('210_sales_channels')
plt.title('Sales channel')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Sales channel'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['189_payment_methods'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('189_payment_methods')
plt.title('Payment method')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Payment method'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['158_charact_organize_products_on_shelves'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('158_charact_organize_products_on_shelves')
plt.title('Products organization')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Products organization'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['157_frequency_organize_shelves'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('157_frequency_organize_shelves')
plt.title('Organization frequency')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Organization frequency'}, ylabel='frequency'>

# %%
Dataframe_final['97_number_of_customers_in_store']=Dataframe_final['97_number_of_customers_in_store'].astype(str)

# %%
Dataframe_final['97_number_of_customers_in_store']

# %%
table4= freq_tbl(Dataframe_final['157_frequency_organize_shelves'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('157_frequency_organize_shelves')
plt.title('Organization frequency')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Organization frequency'}, ylabel='frequency'>

# %%
Dataframe_final['2_current_permanent_employees']=Dataframe_final['2_current_permanent_employees'].astype(str)

# %%
table4= freq_tbl(Dataframe_final['2_current_permanent_employees'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('2_current_permanent_employees')
plt.title('Empleados permanentes')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Empleados permanentes'}, ylabel='frequency'>

# %%
table4= freq_tbl(Dataframe_final['97_number_of_customers_in_store'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('97_number_of_customers_in_store')
plt.title('Clientes en la tienda')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Clientes en la tienda'}, ylabel='frequency'>

# %%
Dataframe_final['4_number_permanent_employees_last_year']=Dataframe_final['4_number_permanent_employees_last_year'].astype(str)

# %%
table4= freq_tbl(Dataframe_final['4_number_permanent_employees_last_year'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('4_number_permanent_employees_last_year')
plt.title('Empleados permanentes el año pasado')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Empleados permanentes'}, ylabel='frequency'>

# %%
Dataframe_final['145_number_direct_competitors']=Dataframe_final['145_number_direct_competitors'].astype(str)

# %%
table4= freq_tbl(Dataframe_final['145_number_direct_competitors'])
Filtro4= table4[table4['frequency']>1]
Filtro4_index= Filtro4.set_index('145_number_direct_competitors')
plt.title('Competidores directos')
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: title={'center': 'Competidores directos'}, ylabel='frequency'>
